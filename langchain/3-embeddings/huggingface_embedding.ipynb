# %%
"""
HuggingFaceEmbeddings is a component from the LangChain library that leverages Hugging Face's transformer models to generate vector representations (embeddings) of text. These embeddings capture semantic meaning, enabling advanced natural language processing tasks.

Real-time use cases include:
- Semantic search: Finding documents or passages similar in meaning to a query.
- Text clustering: Grouping similar texts for topic modeling or organization.
- Recommendation systems: Suggesting content based on semantic similarity.
- Question answering: Matching user questions to relevant answers or documents.
- Chatbots: Understanding user intent and retrieving contextually relevant responses.

By using HuggingFaceEmbeddings, developers can integrate state-of-the-art language models into their applications for improved text understanding and retrieval.
"""

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")

os.environ["USE_CUDA"] = "false"
print(f"USE_CUDA: {os.getenv("USE_CUDA", "false")}")
# Out:
# USE_CUDA: false

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2",
                                   model_kwargs={"device": "cuda" if os.getenv("USE_CUDA", "false") == "true" else "cpu"})
embeddings
# Out:
# HuggingFaceEmbeddings(model_name='all-MiniLM-L6-v2', cache_folder=None, model_kwargs={'device': 'cpu'}, encode_kwargs={}, query_encode_kwargs={}, multi_process=False, show_progress=False)

# %%
text = "this is a test sentence for embedding generation."
query_embedding = embeddings.embed_query(text)
print(query_embedding)
print(len(query_embedding))
# Out:
# [0.0030601820908486843, 0.0020020951051265, 0.055449359118938446, 0.07702641934156418, 0.008578522130846977, 0.059629831463098526, -0.009162819012999535, -0.08298242837190628, 0.014034520834684372, -0.04296578839421272, 0.08602769672870636, -0.06936737149953842, 0.06062674522399902, -0.03547227382659912, -0.026600727811455727, 0.05601983889937401, 0.06927462667226791, -0.00464661093428731, -0.03419388458132744, -0.027563922107219696, 0.021661993116140366, 0.07422768324613571, 0.08340759575366974, -0.042893365025520325, 0.015229546464979649, 0.003309394232928753, -0.04956376180052757, 0.029918739572167397, 0.1258789300918579, -0.001110966899432242, 0.11824702471494675, 0.030489716678857803, -0.0293833389878273, 0.06816587597131729, 0.026447812095284462, 0.08930978924036026, 0.017087072134017944, 0.04911907762289047, 0.017561260610818863, 0.004354082979261875, -0.002572737168520689, -0.03567994385957718, 0.0329633429646492, 0.07110783457756042, 0.02211126498878002, -0.05287946760654449
# ...
