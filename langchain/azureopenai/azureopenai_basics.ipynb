# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("AZURE_OPENAI_API_KEY")
os.environ["OPENAI_ENDPOINT"] = os.getenv("AZURE_OPENAI_ENDPOINT")
os.environ["OPENAI_API_VERSION"] = "2024-12-01-preview"
os.environ["OPENAI_DEPLOYMENT_NAME"] = "gpt-4o-mini"
os.environ["OPENAI_MODEL"] = "gpt-4o-mini"

os.environ["LANGSMITH_TRACING"] = os.getenv("LANGSMITH_TRACING")
os.environ["LANGSMITH_ENDPOINT"] = os.getenv("LANGSMITH_ENDPOINT")
os.environ["LANGSMITH_API_KEY"] = os.getenv("LANGSMITH_API_KEY")
os.environ["LANGSMITH_PROJECT"] = os.getenv("LANGSMITH_PROJECT")
os.environ["LANGSMITH_TRACING_V2"] = os.getenv("LANGSMITH_TRACING_V2")

# %%
from langchain_openai import AzureChatOpenAI
from langchain.schema import HumanMessage, SystemMessage

# Create Azure ChatOpenAI instance
llm = AzureChatOpenAI(
    azure_deployment=os.getenv("OPENAI_DEPLOYMENT_NAME"),  # your deployment name
    api_version=os.getenv("OPENAI_API_VERSION"),           # API version
    azure_endpoint=os.getenv("OPENAI_ENDPOINT"),           # your endpoint URL
    api_key=os.getenv("OPENAI_API_KEY"),                   # your API key
    temperature=0.7,                                        # creativity level
    max_tokens=1000                                         # response length limit
)

print(f"Created Azure ChatOpenAI: {llm}")
# Out:
# Created Azure ChatOpenAI: client=<openai.resources.chat.completions.completions.Completions object at 0x7282b1a2a090> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7282b1b985c0> root_client=<openai.lib.azure.AzureOpenAI object at 0x7282b253a690> root_async_client=<openai.lib.azure.AsyncAzureOpenAI object at 0x7282b19e27e0> temperature=0.7 model_kwargs={} openai_api_key=SecretStr('**********') max_tokens=1000 disabled_params={'parallel_tool_calls': None} azure_endpoint='https://zama-roadmap-to-aiml.openai.azure.com/' deployment_name='gpt-4o-mini' openai_api_version='2024-12-01-preview' openai_api_type='azure'

# %%
# Without template
response = llm.invoke("What is Generative AI?")
print(f"Response: {response.content}")
# Out:
# Response: Generative AI refers to a subset of artificial intelligence techniques that enable machines to create new content, such as text, images, music, and more, rather than simply analyzing or processing existing data. This technology relies on algorithms and models, particularly those based on machine learning and deep learning, to generate outputs that mimic human creativity and produce novel results.
#
# Key characteristics of generative AI include:
#
# 1. **Models**: Generative AI typically employs models like Generative Adversarial Networks (GANs), Variational Autoencoders (VAEs), and transformer-based architectures (e.g., GPT, DALL-E). These models learn from large datasets to understand patterns and structures in the data.
#
# 2. **Content Creation**: It can produce a wide range of content, including:
#    - Text (e.g., writing essays, stories, or summaries)
#    - Images (e.g., generating artwork or realistic photos)
#    - Music (e.g., composing original songs)
#    - Videos (e.g., creating short clips or animations)
#
# 3. **Applications**: Generative AI has various applications across industries, including:
#    - Creative industries (art, music, writing)
#    - Gaming (creating environments or characters)
#    - Advertising (generating marketing content)
#    - Healthcare (designing drug compounds or imaging)
#    - Education (personalized learning materials)
#
# 4. **Ethical Considerations**: The rise of generative AI raises ethical questions regarding copyright, misinformation, and the potential for misuse, such as creating deepfakes or generating harmful content.
#
# Overall, generative AI represents a significant advancement in the field of artificial intelligence, enabling new forms of creativity and innovation while also prompting important discussions about its implications and responsibilities.

# %%
## Chat prompt template
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant that provides information about Generative AI."), 
        ("user", "{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful assistant that provides information about Generative AI.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
#Str Output parser
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
response = output_parser.parse(response.content)
print(f"Parsed response: \n{response}")
# Out:
# Parsed response:
# Generative AI refers to a subset of artificial intelligence techniques that enable machines to create new content, such as text, images, music, and more, rather than simply analyzing or processing existing data. This technology relies on algorithms and models, particularly those based on machine learning and deep learning, to generate outputs that mimic human creativity and produce novel results.
#
# Key characteristics of generative AI include:
#
# 1. **Models**: Generative AI typically employs models like Generative Adversarial Networks (GANs), Variational Autoencoders (VAEs), and transformer-based architectures (e.g., GPT, DALL-E). These models learn from large datasets to understand patterns and structures in the data.
#
# 2. **Content Creation**: It can produce a wide range of content, including:
#    - Text (e.g., writing essays, stories, or summaries)
#    - Images (e.g., generating artwork or realistic photos)
#    - Music (e.g., composing original songs)
#    - Videos (e.g., creating short clips or animations)
#
# 3. **Applications**: Generative AI has various applications across industries, including:
#    - Creative industries (art, music, writing)
#    - Gaming (creating environments or characters)
#    - Advertising (generating marketing content)
#    - Healthcare (designing drug compounds or imaging)
#    - Education (personalized learning materials)
#
# 4. **Ethical Considerations**: The rise of generative AI raises ethical questions regarding copyright, misinformation, and the potential for misuse, such as creating deepfakes or generating harmful content.
#
# Overall, generative AI represents a significant advancement in the field of artificial intelligence, enabling new forms of creativity and innovation while also prompting important discussions about its implications and responsibilities.

# %%
chain = prompt | llm

response = chain.invoke({"input": "What are the applications of Generative AI?"})
print(f"Type of response: {type(response)}")
print(f"Response: \n {response.content}")
# Out:
# Type of response: <class 'langchain_core.messages.ai.AIMessage'>
# Response:
#  Generative AI has a wide range of applications across various fields and industries. Here are some notable applications:
#
# 1. **Content Creation**:
#    - **Text Generation**: Generative AI models like GPT-3 can create articles, stories, poetry, and even code.
#    - **Image Generation**: Tools like DALL-E and Midjourney can generate images from text descriptions, allowing for creative visual content creation.
#    - **Music Composition**: AI can compose original music or assist musicians in generating melodies and harmonies.
#
# 2. **Design and Art**:
#    - **Graphic Design**: AI can assist in creating logos, marketing materials, and other visual content.
#    - **Fashion Design**: Generative models can create new clothing designs or suggest fashion trends based on existing data.
#
# 3. **Gaming**:
#    - **Procedural Content Generation**: AI can generate levels, characters, and narratives in video games, enhancing replayability and creativity.
#    - **Game Character Development**: AI can create unique non-player characters (NPCs) with distinct personalities and behaviors.
#
# 4. **Healthcare**:
#    - **Drug Discovery**: Generative models can help design new molecules or predict the efficacy of drug compounds.
#    - **Medical Imaging**: AI can generate synthetic medical images for training purposes or enhance existing images for better diagnostics.
#
# 5. **Education**:
#    - **Personalized Learning Material**: Generative AI can create quizzes, summaries, and educational content tailored to individual learning styles.
#    - **Language Learning**: AI can generate conversational practice scenarios for language learners.
#
# 6. **Marketing and Advertising**:
#    - **Ad Copy Generation**: AI can generate engaging copy for advertisements tailored to specific audiences.
#    - **Personalized Recommendations**: Generative AI can tailor product recommendations and create personalized marketing content based on user preferences.
#
# 7. **Virtual Worlds and Metaverse**:
#    - **Environment and Asset Creation**: AI can generate 3D models and environments for virtual reality (VR) and augmented reality (AR) applications.
#
# 8. **Finance**:
#    - **Synthetic Data Generation**: AI can create synthetic datasets for training machine learning models, particularly when data is scarce or sensitive.
#    - **Algorithmic Trading**: Generative models can analyze market data and generate trading strategies.
#
# 9. **Legal and Compliance**:
#    - **Document Drafting**: AI can assist in drafting legal documents, contracts, and compliance reports based on templates and existing documents.
#
# 10. **Research and Development**:
#     - **Scientific Research**: AI can generate hypotheses, design experiments, and analyze data in fields such as material science and biology.
#
# 11. **Social Media and Communication**:
#     - **Chatbots and Virtual Assistants**: Generative models can engage in human-like conversations, providing customer support or companionship.
#
# These applications demonstrate the versatility of generative AI, with its ability to enhance creativity, automate tasks, and improve efficiency across various domains. As the technology continues to evolve, new applications are likely to emerge.
