# %%
"""
Langchain Expression Language (LCEL) is a declarative, composable way to build and orchestrate language model workflows. 
It allows users to define chains of operations (such as prompt templates, LLM calls, and output parsing) in a readable and maintainable manner. 
LCEL enables rapid prototyping and productionization of complex language model applications.

Real-Time Use Cases:
1. Conversational AI: Build chatbots that process user input, call LLMs, and parse responses in a pipeline.
2. Document Q&A: Create workflows that retrieve documents, generate context-aware prompts, and extract answers using LLMs.
3. Data Extraction: Automate extraction of structured data from unstructured text using prompt templates and output parsers.
4. Content Generation: Chain together prompt engineering, LLM calls, and post-processing for automated content creation.
5. Agent Workflows: Orchestrate multi-step reasoning tasks where LLMs interact with tools, APIs, or databases.

LCEL simplifies the construction, debugging, and maintenance of these workflows, making it easier to build robust LLM-powered applications.
"""

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file in the parent directory
load_dotenv(dotenv_path="../.env")

# Verify the API key is loaded
groq_api_key = os.getenv("GROQ_API_KEY")
if groq_api_key:
    print(f"GROQ API Key loaded: {groq_api_key[:10]}...{groq_api_key[-4:]}")
    os.environ["GROQ_API_KEY"] = groq_api_key
else:
    print("GROQ API Key not found in environment variables")
    print("Available environment variables with 'GROQ':", [k for k in os.environ.keys() if 'GROQ' in k.upper()])
# Out:
# GROQ API Key loaded: gsk_zZPpr9...ul1p

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate

# Initialize the ChatGroq model
model = ChatGroq(
    model="gemma2-9b-it",
    api_key=os.environ.get("GROQ_API_KEY")
)
model
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x75dca4274c80>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x75dca42752e0>, model_name='gemma2-9b-it', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="Translate from English to French."),
    HumanMessage(content="Hello how are you?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# Bonjour, comment allez-vous ?
